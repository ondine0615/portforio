# %%
from kafka import KafkaProducer
import requests
from bs4 import BeautifulSoup as bs
import re
from time import sleep
import json

def clean_text(text):
        cleaned_text = re.sub('[a-zA-Z]','',text)
        cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '', cleaned_text)
        return cleaned_text

URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
my_arr=[]
compare={'url':0}
is_first=True
target=["에르메스","루이비통","디올","프라다","구찌","샤넬"]
excepts=["삽니다","매입","구매","구입"]
    
while True:

    html=requests.get(URL)
    soup=html.text
    par_soup=bs(soup, 'html.parser')
    tr_arr=par_soup.select("#main-area > div:nth-child(4) > table > tbody > tr")  
    TOPIC_NAME="test"

    for tr in tr_arr:
        is_new_item=True
        a_tag=tr.select_one('td.td_article > div.board-list > div > a')
        map = {
            "title":a_tag.text.strip(),
            "url":'https://cafe.naver.com' + a_tag["href"],
            "is_checked":False
        }
        for element in my_arr:
            if element['url'] == map["url"]:
                is_new_item==False
                break
        if is_new_item==True:
            my_arr.insert(0,map)
            print(map)
# Out:
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# ...
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# {'title': '에르메스 미니 볼리드 블랙 금장', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455358&referrerAllArticles=false', 'is_checked': False}
# {'title': '(미개봉) 에르메스 가든파티 30 부겡빌리에', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455349&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR3964 숄더백 택포16.3', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455196&referrerAllArticles=false', 'is_checked': False}
# {'title': "비비안웨스트우드 '찰리 타탄 파우치'", 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455162&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬 골든볼 벨트백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455117&referrerAllArticles=false', 'is_checked': False}
# {'title': '새제품) 샤넬 어피니티 미듐 캐비어 블랙', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944455090&referrerAllArticles=false', 'is_checked': False}
# {'title': '정품 고야드 미니앙주 그레이 색상 + 이너백 풀박', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454960&referrerAllArticles=false', 'is_checked': False}
# {'title': '[정품] 듀퐁 서류가방 브라운 새상품 초초특가에 팝니다 (백화점AS가능) (카드할부가능)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454922&referrerAllArticles=false', 'is_checked': False}
# {'title': '디올 레이디백  스몰 파드', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454702&referrerAllArticles=false', 'is_checked': False}
# {'title': '루이비통 알마비비 다미에 (정품)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454634&referrerAllArticles=false', 'is_checked': False}
# {'title': '\ufeff프라다 BR4135 비텔로샤인 체인 빅숄더 택포15.5', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454249&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬. 정품 CC로퍼. 240', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454235&referrerAllArticles=false', 'is_checked': False}
# {'title': '살바토레 페레가모 바라백', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454215&referrerAllArticles=false', 'is_checked': False}
# {'title': '샤넬woc19(새상품급)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454149&referrerAllArticles=false', 'is_checked': False}
# {'title': '(새상품)샤넬 클래식woc 블랙 캐비어 금장 내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944454026&referrerAllArticles=false', 'is_checked': False}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 22>()
#      22 html=requests.get(URL)
#      23 soup=html.text
# ---> 24 par_soup=bs(soup, 'html.parser')
#      25 tr_arr=par_soup.select("#main-area > div:nth-child(4) > table > tbody > tr")
#      26 TOPIC_NAME="test"
#
# File ~/anaconda3/envs/kafka/lib/python3.8/site-packages/bs4/__init__.py:333, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     331 self.builder.initialize_soup(self)
#     332 try:
# --> 333     self._feed()
#     334     success = True
#     335     break
#
# File ~/anaconda3/envs/kafka/lib/python3.8/site-packages/bs4/__init__.py:451, in BeautifulSoup._feed(self)
#     448 # Convert the document to Unicode.
#     449 self.builder.reset()
# --> 451 self.builder.feed(self.markup)
#     452 # Close out any unfinished strings and close all the open tags.
#     453 self.endData()
#
# File ~/anaconda3/envs/kafka/lib/python3.8/site-packages/bs4/builder/_htmlparser.py:399, in HTMLParserTreeBuilder.feed(self, markup)
#     397 parser.soup = self.soup
#     398 try:
# --> 399     parser.feed(markup)
#     400     parser.close()
#     401 except HTMLParseError as e:
#
# File ~/anaconda3/envs/kafka/lib/python3.8/html/parser.py:111, in HTMLParser.feed(self, data)
#     105 r"""Feed data to the parser.
#     106
#     107 Call this as often as you want, with as little or as much text
#     108 as you want (may include '\n').
#     109 """
#     110 self.rawdata = self.rawdata + data
# --> 111 self.goahead(0)
#
# File ~/anaconda3/envs/kafka/lib/python3.8/html/parser.py:171, in HTMLParser.goahead(self, end)
#     169 if startswith('<', i):
#     170     if starttagopen.match(rawdata, i): # < + letter
# --> 171         k = self.parse_starttag(i)
#     172     elif startswith("</", i):
#     173         k = self.parse_endtag(i)
#
# File ~/anaconda3/envs/kafka/lib/python3.8/html/parser.py:345, in HTMLParser.parse_starttag(self, i)
#     343     self.handle_startendtag(tag, attrs)
#     344 else:
# --> 345     self.handle_starttag(tag, attrs)
#     346     if tag in self.CDATA_CONTENT_ELEMENTS:
#     347         self.set_cdata_mode(tag)
#
# File ~/anaconda3/envs/kafka/lib/python3.8/site-packages/bs4/builder/_htmlparser.py:154, in BeautifulSoupHTMLParser.handle_starttag(self, name, attrs, handle_empty_element)
#     152 #print("START", name)
#     153 sourceline, sourcepos = self.getpos()
# --> 154 tag = self.soup.handle_starttag(
#     155     name, None, None, attr_dict, sourceline=sourceline,
#     156     sourcepos=sourcepos
#     157 )
#     158 if tag and tag.is_empty_element and handle_empty_element:
#     159     # Unlike other parsers, html.parser doesn't send separate end tag
#     160     # events for empty-element tags. (It's handled in
#    (...)
#     166     # don't want handle_endtag() to cross off any previous end
#     167     # events for tags of this name.
#     168     self.handle_endtag(name, check_already_closed=False)
#
# File ~/anaconda3/envs/kafka/lib/python3.8/site-packages/bs4/__init__.py:694, in BeautifulSoup.handle_starttag(self, name, namespace, nsprefix, attrs, sourceline, sourcepos, namespaces)
#     690         most_recently_popped = self.popTag()
#     692     return most_recently_popped
# --> 694 def handle_starttag(self, name, namespace, nsprefix, attrs, sourceline=None,
#     695                     sourcepos=None, namespaces=None):
#     696     """Called by the tree builder when a new tag is encountered.
#     697
#     698     :param name: Name of the tag.
#    (...)
#     711     don't call handle_endtag.
#     712     """
#     713     # print("Start tag %s: %s" % (name, attrs))
#
# KeyboardInterrupt:

# %%
from kafka import KafkaProducer
import requests
from bs4 import BeautifulSoup as bs
import re
from time import sleep
import json

def clean_text(text):
        cleaned_text = re.sub('[a-zA-Z]','',text)
        cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '', cleaned_text)
        return cleaned_text

#URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
my_arr=[]
#compare={'url':0}
#is_first=True
target=["에르메스","루이비통","디올","프라다","구찌","샤넬"]
excepts=["삽니다","매입","구매","구입"]
recentSubject=""
#my_arr=[]
#brokers=["localhost:9091","localhost:9092","localhost:9093"]
#producer = KafkaProducer(bootstrap_servers=brokers)


#while True:

BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
with requests.Session() as s:
    res=s.get(BASE_URL)
    if res.status_code==requests.codes.ok:
        par_soup=bs(res.text, 'html.parser')
        number=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-number > div").text
        tr_arr
        #main-area > div:nth-child(4) > table > tbody > tr:nth-child(1)
        #main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-list > div > a
        #print(number)
        if recentSubject==number:
            print("reload")
#            continue
        elif recentSubject !=number:
            recentSubject=number
            tr_arr=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr")
            a_tag=tr_arr.select_one('td.td_article > div.board-list > div > a')
            map = {
            "title":a_tag.text.strip(),
            "url":'https://cafe.naver.com' + a_tag["href"],
            "is_checked": False,
            }
            print(map)
        if any(x in map["title"] for x in target) and not any(x in map["title"] for x in excepts):
            clean_msg=clean_text(map["title"])
            #print(clean_msg)
            msg_split=clean_msg.split(" ")
            for ms in msg_split:
                if ms in target:
                    map['brand']=ms
                    print(map)
# Out:
# {'title': '디올 링고 메신저백_Dior lingot_22년7월구매_백화점풀구성', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944480926&referrerAllArticles=false', 'is_checked': False}

# %%
from kafka import KafkaProducer
import requests
from bs4 import BeautifulSoup as bs
import re
from time import sleep
import json

def clean_text(text):
        cleaned_text = re.sub('[a-zA-Z]','',text)
        cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '', cleaned_text)
        return cleaned_text

#URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
my_arr=[]
#compare={'url':0}
#is_first=True
target=["에르메스","루이비통","디올","프라다","구찌","샤넬"]
excepts=["삽니다","매입","구매","구입"]
recentSubject=""

BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
with requests.Session() as s:
    res=s.get(BASE_URL)
    if res.status_code==requests.codes.ok:
        par_soup=bs(res.text, 'html.parser')

tr_arr=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr>td.td_article > div.board-list > div > a")  
print(tr_arr)
map = {
    "title":tr_arr.text.strip(),
    "url":'https://cafe.naver.com' + tr_arr["href"]
}
# Out:
# <a class="article" href="/ArticleRead.nhn?clubid=10050146&amp;page=1&amp;menuid=782&amp;boardtype=L&amp;articleid=944480533&amp;referrerAllArticles=false" onclick="clickcr(this, 'gdb.title','','',event);">
#
#
#
#
#
#
#
#
#
#                                     발리 핸드백
#
#
#                             </a>

# %%
map
# Out:
# {'title': '발리 핸드백',
#  'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944480533&referrerAllArticles=false'}

# %%
tr_arr
# Out:
# <a class="article" href="/ArticleRead.nhn?clubid=10050146&amp;page=1&amp;menuid=782&amp;boardtype=L&amp;articleid=944478894&amp;referrerAllArticles=false" onclick="clickcr(this, 'gdb.title','','',event);">
#
#
#
#
#
#
#
#
#
#                                     (정품) 토즈 토트백
#
#
#                             </a>

# %%
recentSubject=""
my_arr=[]

BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
with requests.Session() as s:
    res=s.get(BASE_URL)
    if res.status_code==requests.codes.ok:
        par_soup=bs(res.text, 'html.parser')
        article=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-list > div > a").text
        article = re.sub(r'\n', '', article)
        print(article)
        
        if recentSubject !=article:
            
            my_arr.insert(0,article)
            
            print(my_arr)
# Out:
#                                                                                                                                                                                                                                                                         고야드 가방팝니다 벨베데르pm
# ['                                                                                                                                                                                                                                                                        고야드 가방팝니다 벨베데르pm                                                                                                ']

# %%
recentSubject=""
my_arr=[]
BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"

#while True:    
with requests.Session() as s:
    res=s.get(BASE_URL)
    if res.status_code==requests.codes.ok:
        par_soup=bs(res.text, 'html.parser')
        number=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-number > div").text
        print(number)
# Out:
# 944475719

# %%
recentSubject=""
my_arr=[]
BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"

while True:    
    with requests.Session() as s:
        res=s.get(BASE_URL)
        if res.status_code==requests.codes.ok:
            par_soup=bs(res.text, 'html.parser')
            number=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-number > div").text
            #print(number)
            if recentSubject==number:
                print('there is no new product')
                sleep(10)
                continue
            elif recentSubject !=number:
                recentSubject=number
                print(recentSubject)
                tr_arr=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr")
                a_tag=tr_arr.select_one('td.td_article > div.board-list > div > a')
                map = {
                "title":a_tag.text.strip(),
                "url":'https://cafe.naver.com' + a_tag["href"]
                }
                print(map)
                sleep(10)
# Out:
# 944481324
# {'title': '코치 coach 미니크로스백 운포55000', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944481324&referrerAllArticles=false'}
# there is no new product
# 944481494
# {'title': '미개봉 새상품))샤넬 클래식WOC 캐비어/금장/내장칩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944481494&referrerAllArticles=false'}
# there is no new product
# there is no new product
# 944481602
# {'title': '브로말리 백팩', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944481602&referrerAllArticles=false'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [149], in <cell line: 6>()
#      21 map = {
#      22 "title":a_tag.text.strip(),
#      23 "url":'https://cafe.naver.com' + a_tag["href"]
#      24 }
#      25 print(map)
# ---> 26 sleep(10)
#
# KeyboardInterrupt:

# %%
target=["에르메스","루이비통","디올","프라다","구찌","샤넬"]
excepts=["삽니다","매입","구매","구입"]
recentSubject=""
# Out:
# {'title': '브로말리 백팩',
#  'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944481602&referrerAllArticles=false'}

# %%
if any(x in map["title"] for x in target) and not any(x in map["title"] for x in excepts):
    print(map)

# %%
a=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(2) > td.td_article > div.board-list > div > span.list-i-selling").text

# %%
# Out:
# '판매'

# %%
a_tag=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-list > div > a")
map = {
    "title":a_tag.text.strip(),
    "url":'https://cafe.naver.com' + a_tag["href"],
    "is_checked": False,
}
print(map)
# Out:
# {'title': '정품 샤넬 블랙 클러치 라지', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944476149&referrerAllArticles=false', 'is_checked': False}

# %%
test=["샤넬급처","합니다"]

# %%
matching=[s for s in test if "샤넬" in s]
print()
# Out:
# ['샤넬급처']

# %%
while True:    
    with requests.Session() as s:
        BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
        res=s.get(BASE_URL)
        par_soup=bs(res.text, 'html.parser')
        tr_arr=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr")
        a_tag=tr_arr.select_one('td.td_article > div.board-list > div > a')
        map = {
            "title":a_tag.text.strip(),
            "url":'https://cafe.naver.com' + a_tag["href"],
            "is_checked": False,
        }
        print(map)
# Out:
# {'title': '샤넬 클래식 라지 캐비어 (상태최상)', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944477041&referrerAllArticles=false', 'is_checked': False}

# %%
from kafka import KafkaProducer
import requests
from bs4 import BeautifulSoup as bs
import re
from time import sleep
import json


def clean_text(text):
        cleaned_text = re.sub('[a-zA-Z]','',text)
        cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '', cleaned_text)
        return cleaned_text


#compare={'url':0}
#is_first=True
target=["에르메스","루이비통","디올","프라다","구찌","샤넬","메종마르지엘라"]
excepts=["삽니다","매입","구매","구입"]

recentSubject=""
matching=""
my_arr=[]
#BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"

while True:    
    with requests.Session() as s:
        BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
        res=s.get(BASE_URL)
        if res.status_code==requests.codes.ok:
            par_soup=bs(res.text, 'html.parser')
            number=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-number > div").text
            print(number)
            if recentSubject==number:
                print('there is no new product')
                sleep(1)
                continue
            elif recentSubject !=number:
                recentSubject=number
                print(recentSubject)
                tr_arr=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr")
                a_tag=tr_arr.select_one('td.td_article > div.board-list > div > a')
                map = {
                "title":a_tag.text.strip(),
                "url":'https://cafe.naver.com' + a_tag["href"]
                }
                #print(map)
                sleep(1)
            if any(x in map["title"] for x in target) and not any(x in map["title"] for x in excepts):
                clean_msg=clean_text(map["title"])
                msg_split=clean_msg.split(" ")
                
                
#                 matching=[s for s in msg_split if target in s]
#                 if matching==[]:
#                     map['brand']='None'
#                 else:
#                     map['brand']=matching
#                 print(map)

            for s in msg_split:
                for tar in target:
                    if s in target:
                        matching+=s
                        break
                    else:
                        matching="None"
            print(matching)
# Out:
# 944554032
# 944554032
# None
# 944554032
# there is no new product
# 944554032
# there is no new product
# 944554032
# there is no new product
# 944554032
# there is no new product
# 944554032
# there is no new product
# 944554032
# there is no new product
# 944554032
# there is no new product
# 944554032
# there is no new product
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [222], in <cell line: 26>()
#      33 if recentSubject==number:
#      34     print('there is no new product')
# ---> 35     sleep(1)
#      36     continue
#      37 elif recentSubject !=number:
#
# KeyboardInterrupt:

# %%
map
# Out:
# {'title': '메종마르지엘라 5ac버킷백 화이트',
#  'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944517956&referrerAllArticles=false'}

# %%
clean_msg=clean_text(map["title"])
msg_split=clean_msg.split(" ")
print(clean_msg)

for s in msg_split:
    print(s)
for tar in target:
    matching=[s for s in msg_split if tar in s]
    if matching=[]:
        matching=
print(matching)
# Out:
# 메종마르지엘라 5버킷백 화이트
# 메종마르지엘라
# 5버킷백
# 화이트
# ['메종마르지엘라']

# %%
msg=map['title']
msg
# Out:
# '메종마르지엘라 5ac버킷백 화이트'

# %%
target
# Out:
# ['에르메스', '루이비통', '디올', '프라다', '구찌', '샤넬', '메종마르지엘라']

# %%
for tar in target:
    matching = [ms for ms in msg if tar in ms]
print(matching)
# Out:
# []

# %%
test={'title': '샤넬 코코체인 카드지갑 캐비어 블랙 금장 AP2306 31번대', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944527848&referrerAllArticles=false'}

# %%
test
# Out:
# {'title': '샤넬 코코체인 카드지갑 캐비어 블랙 금장 AP2306 31번대',
#  'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944527848&referrerAllArticles=false'}

# %%
_title=test['title']

# %%
tit=_title.split(" ")

# %%
tit
# Out:
# ['샤넬', '코코체인', '카드지갑', '캐비어', '블랙', '금장', 'AP2306', '31번대']

# %%
for s in tit:
    print(s)
    if tar in s:
        print(tar)
# Out:
# 샤넬
# 코코체인
# 카드지갑
# 캐비어
# 블랙
# 금장
# AP2306
# 31번대

# %%
matching=""
for s in tit:
    for tar in target:
        if s in target:
            matching+=s
            break
        else:
            matching="None"
print(matching)
# Out:
# 샤넬

# %%
for tar in target:
    for s in tit:
        if s in target:
            
            matching=[s for s in tit if tar in s]

if matching==[]:
    print('타겟이 아닙니다')
print(matching)
# Out:
# 타겟이 아닙니다
# []

# %%
while True:
    with requests.Session() as s:
            BASE_URL="https://cafe.naver.com/ArticleList.nhn?search.clubid=10050146&search.menuid=782&search.boardtype=L"
            res=s.get(BASE_URL)
            if res.status_code==requests.codes.ok:
                par_soup=bs(res.text, 'html.parser')
                number=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr:nth-child(1) > td.td_article > div.board-number > div").text
                print("게시물 번호:",number)
                if recentSubject==number:
                    print('there is no new product')
                    sleep(10)
                    continue
                elif recentSubject !=number:
                    recentSubject=number
                    print(recentSubject)
                    tr_arr=par_soup.select_one("#main-area > div:nth-child(4) > table > tbody > tr")
                    a_tag=tr_arr.select_one('td.td_article > div.board-list > div > a')
                    map = {
                    "title":a_tag.text.strip(),
                    "url":'https://cafe.naver.com' + a_tag["href"]
                    }
                    #print(map)
                    
                if any(x in map["title"] for x in target) and not any(x in map["title"] for x in excepts):
                    clean_msg=clean_text(map["title"])
                    msg_split=clean_msg.split(" ")


    #                 matching=[s for s in msg_split if target in s]
    #                 if matching==[]:
    #                     map['brand']='None'
    #                 else:
    #                     map['brand']=matching
    #                 print(map)

                for s in msg_split:
                    for tar in target:
                        if s in target:
                            map["brand"]=s
                        else:
                            map['brand']="others"
                print(map)
                sleep(10)
# Out:
# 게시물 번호: 944556914
# 944556914
# {'title': '샤넬 공방 베니티', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944556914&referrerAllArticles=false', 'brand': 'None'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [230], in <cell line: 2>()
#      41             map['brand']="None"
#      42 print(map)
# ---> 43 sleep(10)
#
# KeyboardInterrupt:

# %%
test={'title': '샤넬 공방 베니티', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944556914&referrerAllArticles=false'}

# %%
tt=test['title']
clean_msg=clean_text(tt)

# %%
tt
# Out:
# '샤넬 공방 베니티'

# %%
msg_split=clean_msg.split(" ")
print(msg_split)
# Out:
# ['샤넬', '공방', '베니티']

# %%
for s in msg_split:
    for tar in target:
        if s in tar:
            map['brand']=s
print(map)
# Out:
# {'title': '샤넬 공방 베니티', 'url': 'https://cafe.naver.com/ArticleRead.nhn?clubid=10050146&page=1&menuid=782&boardtype=L&articleid=944556914&referrerAllArticles=false', 'brand': '샤넬'}
